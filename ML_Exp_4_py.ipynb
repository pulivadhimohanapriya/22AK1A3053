# %% [markdown]
# <a href="https://colab.research.google.com/github/pulivadhimohanapriya/22AK1A3053/blob/main/ML_Exp_4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
np.random.seed(123)
x=np.random.normal(0,1,100)
y=x+np.random.normal(0,0.5,100)
data=pd.DataFrame({'x' : x ,'y' : y})
scaler=StandardScaler()
scaled_data=scaler.fit_transform(data)
pca=PCA(n_components=2)
pca_result=pca.fit_transform(scaled_data)
print(pca.explained_variance_ratio_)
plt.scatter(pca_result[:,0],pca_result[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()
# Out:
# [0.9587646 0.0412354]
